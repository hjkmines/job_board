# %%
import scraper
import pandas as pd
from datetime import date
import requests
import json
import csv
import html

# %%
today = date.today()

# Web scrapers
dice_df = scraper.scrape_dice()

dice_df.to_json(f'dice_{today}.json')

indeed_df = scraper.scrape_indeed()

indeed_df.to_json(f'indeed_{today}.json')

# %%
def get_companies(filename: str):
    with open('companies.csv', 'r') as data:
        companies = {row[0]: row[1] for row in csv.reader(data)}
    companies_clean = companies
    companies_bad = {}
    tokens = set(companies.keys())
    for token in tokens:
        if not requests.get(f'https://boards-api.greenhouse.io/v1/boards/{token}/jobs'):
            companies_clean.pop(token)
            companies_bad[token] = companies.get(token)

    if companies_bad:
        with open(f"./logs/companies_bad_{date.today()}.json", "w") as out:
            json.dump(companies_bad, out)
            
    return companies_clean

 # # Main Code
    # Finds jobs and outputs results as csv or excel file

    # Return a list of eligible jobs from a set of companies

# %%
# Greenhouse API
companies_file = 'companies.csv'

roles = {'developer','engineer', 'frontend', 'software', 'apprentice', 'apprenticeship', 'front-end', 'backend', 'back-end', 'jr.', 'jr' }

# Includes 'software' for titles that are just 'software engineer', etc.
levels = {'junior', 'entry-level', 'grad', 'graduate', 'apprentice', 'apprenticeship', 'software', 'entry', 'intern', 'i', '1', 'associate'}

# Optional, but helps exclude higher level positions
exclude = {'senior', 'principal' , 'sr.', 'ii', 'iii' }

criteria ={'roles': roles, 'levels': levels, 'exclude' : exclude}

companies = get_companies(companies_file)


greenhouse_df = scraper.scrape_greenhouse(companies, criteria)

# %%
greenhouse_df
# Out:
#                                       title           company  \
# 0         Software Engineer, Infrastructure      Loyal Health
# 1                Software Engineer, Backend      Janus Health
# 2                         Software Engineer         Stariwell
# 3             Application Software Engineer  Applied Intution
# 4             Application Software Engineer  Applied Intution
# ..                                      ...               ...
# 223  Software Support Specialist (Weekends)          Storable
# 224                       Software Engineer         Watershed
# 225     Software Engineer, Video Streaming       Flock Safety
# 226                       Software Engineer              Viam
# 227              Software Engineer, Product             Level
#
#                                                   link  \
# 0    https://boards.greenhouse.io/loyal/jobs/477271...
# 1    https://boards.greenhouse.io/janushealth/jobs/...
# 2    https://boards.greenhouse.io/stairwell/jobs/43...
# 3    https://boards.greenhouse.io/appliedintuition/...
# 4    https://boards.greenhouse.io/appliedintuition/...
# ..                                                 ...
# 223  https://boards.greenhouse.io/storable/jobs/481...
# 224  https://boards.greenhouse.io/watershed/jobs/42...
# 225  https://boards.greenhouse.io/flocksafety/jobs/...
# 226  https://boards.greenhouse.io/viamrobotics/jobs...
# 227  https://boards.greenhouse.io/level/jobs/552442...
#
#                                            description  \
# 0    <div class="content-intro"><p>Loyal is an orga...
# 1    <div class="content-intro"><p>At Janus, we bel...
# 2    <div class="content-intro"><h3>We’re expanding...
# 3    <div class="content-intro"><p><strong>About Ap...
# 4    <div class="content-intro"><p><strong>About Ap...
# ..                                                 ...
# 223  <p>Storable&nbsp;is seeking a&nbsp;Software Su...
# 224  <p><span style="text-decoration: underline;">R...
# 225  <h2><span style="color: #30d15e;"><strong>Comp...
# 226  <div class="content-intro"><p>Viam is a roboti...
# 227  <div class="content-intro"><p>At Level, we bel...
#
#                           date remote  greenhouse_id  \
# 0    2023-03-08T18:14:34-05:00  False     4772718004
# 1    2023-03-11T01:37:04-05:00   True     4012385007
# 2    2022-06-02T14:21:25-04:00   True     4316724004
# 3    2023-03-21T14:50:45-04:00  False     4045084005
# 4    2023-03-21T14:50:45-04:00  False     4045011005
# ..                         ...    ...            ...
# 223  2023-03-01T12:06:57-05:00  False     4813312004
# 224  2023-02-14T18:53:40-05:00  False     4254100003
# 225  2023-02-21T12:58:56-05:00   None     6627948002
# 226  2023-02-10T13:14:31-05:00  False     4552131004
# 227  2023-03-21T20:10:14-04:00   True     5524427003
#
#                                     greenhouse_api_url  \
# 0    https://boards-api.greenhouse.io/v1/boards/loy...
# 1    https://boards-api.greenhouse.io/v1/boards/jan...
# 2    https://boards-api.greenhouse.io/v1/boards/sta...
# 3    https://boards-api.greenhouse.io/v1/boards/app...
# 4    https://boards-api.greenhouse.io/v1/boards/app...
# ..                                                 ...
# 223  https://boards-api.greenhouse.io/v1/boards/sto...
# 224  https://boards-api.greenhouse.io/v1/boards/wat...
# 225  https://boards-api.greenhouse.io/v1/boards/flo...
# 226  https://boards-api.greenhouse.io/v1/boards/via...
# 227  https://boards-api.greenhouse.io/v1/boards/lev...
#
#                                               location
# 0    [{'id': 4009356004, 'name': 'Anywhere in the U...
# 1    [{'id': 4000619007, 'name': 'Remote', 'locatio...
# 2    [{'id': 4025374004, 'name': 'Remote', 'locatio...
# 3    [{'id': 4009577005, 'name': 'Stockholm', 'loca...
# 4    [{'id': 4009261005, 'name': 'Seoul', 'location...
# ..                                                 ...
# 223  [{'id': 4012074004, 'name': 'USA', 'location':...
# 224  [{'id': 4018757003, 'name': 'Main Office', 'lo...
# 225                                                NaN
# 226  [{'id': 4027040004, 'name': 'Bend, OR', 'locat...
# 227  [{'id': 4005479003, 'name': 'New York', 'locat...
#
# [228 rows x 9 columns]

# %%
indeed_df
# Out:
#                                     job_title                     company  \
# 0                    Junior Software Engineer                      MP RPO
# 1                   Junior Software Developer             ISPA Technology
# 2                  Junior Level PHP Developer  American Partner Solutions
# 3                            Junior Developer                   FinMC LLC
# 4                      Jr. Software Developer       Omphalos Lifesciences
# 5                            Junior Developer                         JST
# 6                     Staff Software Engineer            Home Depot / THD
# 7                    Junior Software Engineer                   Concept3D
# 8                   Junior Software Developer                        CACI
# 9                        Junior Web Developer                        AMDA
# 10  Junior Level Software Engineer - SKA IV&V           4M Research, Inc.
# 11                     Junior UX/UI Developer            Red Technologies
# 12           Junior Software Reverse Engineer                     Parsons
# 13             Junior .Net Software Developer                     Peraton
# 14                      Junior Java Developer             Agri Stats, Inc
#
#                                                  link  \
# 0   https://www.indeed.com/rc/clk?jk=002a28d218304...
# 1   https://www.indeed.com/rc/clk?jk=02b9f0af6bb6d...
# 2   https://www.indeed.com/rc/clk?jk=a534d1cfd4eb5...
# 3   https://www.indeed.com/company/Financial-Media...
# 4   https://www.indeed.com/company/Omphalos-Lifesc...
# 5   https://www.indeed.com/rc/clk?jk=5fe11b89efe34...
# 6   https://www.indeed.com/rc/clk?jk=17c24d0e3aa78...
# 7   https://www.indeed.com/rc/clk?jk=871782c66b2dc...
# 8   https://www.indeed.com/rc/clk?jk=fc8b51c05d4e4...
# 9   https://www.indeed.com/rc/clk?jk=a344880db2927...
# 10  https://www.indeed.com/rc/clk?jk=52f6367523330...
# 11  https://www.indeed.com/rc/clk?jk=1b060ae468c00...
# 12  https://www.indeed.com/rc/clk?jk=a9f258cf170c3...
# 13  https://www.indeed.com/rc/clk?jk=b3f7882b6508d...
# 14  https://www.indeed.com/company/Agri-Stats,-Inc...
#
#                                           description  \
# 0   \nWho you are: \nMP's client is looking to bri...
# 1   \nJunior Software Developer\nWe are looking fo...
# 2   \n\nIf you are a Jr. PHP Developer with experi...
# 3   About FinMC\nFinMC is a financial publishing c...
# 4   Company Overview:\nOmphalos Lifesciences is a ...
# 5   \nOverview\n JST is currently seeking a Junior...
# 6   \n\nPosition Purpose:\n The Staff Software Eng...
# 7   \nAbout Concept3D\n Founded in 2006, Concept3D...
# 8   \n Junior Software Developer\n  Job Category: ...
# 9   \nAMDA College and Conservatory of the Perform...
# 10  \nAre you looking for a career with a company ...
# 11  \n\nRed Technologies is a fast-growing company...
# 12  \n In a world of possibilities, pursue one wit...
# 13  \n Responsibilities: \n \n   Peraton is search...
# 14  Junior Java Developer - Agri Stats\nDo you hav...
#
#                       date_posted  min_salary  max_salary salary_type  \
# 0   Thu, 23 Mar 2023 20:49:14 GMT     60000.0    100000.0        YEAR
# 1   Thu, 23 Mar 2023 22:23:45 GMT         NaN         NaN        None
# 2   Thu, 23 Mar 2023 22:05:35 GMT         NaN         NaN        None
# 3   Thu, 23 Mar 2023 22:20:23 GMT     40000.0        -1.0        YEAR
# 4   Thu, 23 Mar 2023 21:17:52 GMT     70000.0        -1.0        YEAR
# 5   Thu, 23 Mar 2023 20:36:43 GMT         NaN         NaN        None
# 6   Thu, 23 Mar 2023 21:26:37 GMT         NaN         NaN        None
# 7   Thu, 23 Mar 2023 20:47:33 GMT     60000.0    100000.0        YEAR
# 8   Thu, 23 Mar 2023 22:29:26 GMT     45300.0     90600.0        YEAR
# 9   Fri, 24 Mar 2023 00:10:36 GMT     65000.0     70000.0        YEAR
# 10  Thu, 23 Mar 2023 20:43:10 GMT         NaN         NaN        None
# 11  Thu, 23 Mar 2023 18:45:47 GMT         NaN         NaN        None
# 12  Thu, 23 Mar 2023 14:35:57 GMT     59300.0    103800.0        YEAR
# 13  Thu, 23 Mar 2023 08:10:21 GMT     40000.0        -1.0        YEAR
# 14  Thu, 23 Mar 2023 18:43:01 GMT     67000.0     95000.0        YEAR
#
#                  city country
# 0              Remote      US
# 1   Panama City Beach      US
# 2               Tampa      US
# 3              Remote      US
# 4              Dallas      US
# 5          Washington      US
# 6             Atlanta      US
# 7              Remote      US
# 8               Omaha      US
# 9         Los Angeles      US
# 10         Huntsville      US
# 11       Indianapolis      US
# 12         Huntsville      US
# 13         Charleston      US
# 14         Fort Wayne      US

# %%
dice_df
# Out:
#                                  title                    company  \
# 0             Junior Software Engineer    Lincoln Financial Group
# 1            Junior Software Developer  Acadia Technologies, Inc.
# 2                Jr Software Developer              Honu Services
# 3   Jr. Application Developer (SQL,...      Randstad Technologies
# 4            Junior Software Developer  Nigel Frank International
# 5      Jr. Software Engineer- Embedded            ConsultNet, LLC
# 6       Jr. Software Engineer (TS/SCI)         MAXAR Technologies
# 7            Junior Software Developer         Evoke Technologies
# 8             JUNIOR SOFTWARE ENGINEER                 Incedo Inc
# 9             Junior Software Engineer                      Jobot
# 10            Junior Software Engineer                      Jobot
# 11            Junior Software Engineer                      Jobot
# 12       Junior Software Engineer /...         Motion Recruitment
# 13            Junior Software Engineer   Turnberry Solutions, Inc
# 14           Junior Software Developer                Robert Half
# 15           Junior Software Developer         Aditi Staffing LLC
# 16    Junior SW Engineer (React and...         Prodware Solutions
# 17           JUNIOR SOFTWARE DEVELOPER         HRK Solutions LLC.
# 18     ISD Engineer I (Jr. Software...  Navy Federal Credit Union
# 19     ISD Engineer I (Jr. Software...  Navy Federal Credit Union
#
#                                                  link  \
# 0   https://www.dice.com/jobs/detail/Junior-Softwa...
# 1   https://www.dice.com/jobs/detail/Junior-Softwa...
# 2   https://www.dice.com/jobs/detail/Jr-Software-D...
# 3   https://www.dice.com/jobs/detail/Jr.-Applicati...
# 4   https://www.dice.com/jobs/detail/Junior-Softwa...
# 5   https://www.dice.com/jobs/detail/Jr.-Software-...
# 6   https://www.dice.com/jobs/detail/Jr.-Software-...
# 7   https://www.dice.com/jobs/detail/Junior-Softwa...
# 8   https://www.dice.com/jobs/detail/JUNIOR-SOFTWA...
# 9   https://www.dice.com/jobs/detail/Junior-Softwa...
# 10  https://www.dice.com/jobs/detail/Junior-Softwa...
# 11  https://www.dice.com/jobs/detail/Junior-Softwa...
# 12  https://www.dice.com/jobs/detail/Junior-Softwa...
# 13  https://www.dice.com/jobs/detail/Junior-Softwa...
# 14  https://www.dice.com/jobs/detail/Junior-Softwa...
# 15  https://www.dice.com/jobs/detail/Junior-Softwa...
# 16  https://www.dice.com/jobs/detail/Junior-SW-Eng...
# 17  https://www.dice.com/jobs/detail/JUNIOR-SOFTWA...
# 18  https://www.dice.com/jobs/detail/ISD-Engineer-...
# 19  https://www.dice.com/jobs/detail/ISD-Engineer-...
#
#                                           description  \
# 0   Alternate Locations: Work from Home   Work Arr...
# 1    Work experience in software or web developmen...
# 2   Location: Nationwide with preference for DC me...
# 3   job summary:As a Jr. Application Developer, yo...
# 4   Junior Software DeveloperI am currently workin...
# 5   Job DescriptionJr. Software Engineer- Embedded...
# 6   Please review the job details below.Maxar is s...
# 7   Position: Junior Software Developer Location: ...
# 8   Associate Software Engineer -  Responsibilitie...
# 9   My client is a well known software company foc...
# 10  My client is a well known software company foc...
# 11  My client is a well known software company foc...
# 12  A music media company based in Philadelphia, P...
# 13  Duration: FTELocation: 100% RemoteOverview: Cr...
# 14  Description Robert Half Technology is currentl...
# 15  Job Title: Junior Software DeveloperLocation: ...
# 16  SW EngineerLocation: remote/Chicago IL / India...
# 17  REQUIRED SKILLS: 1. 0 -3 years in "Data Engine...
# 18  YOUR LIFE'S MISSION: POSSIBLE  You have goals,...
# 19  YOUR LIFE'S MISSION: POSSIBLE  You have goals,...
#
#                  date_posted           country state              city    zip  \
# 0   2023-02-02T23:26:03.000Z            Radnor    PA            Radnor  19087
# 1   2023-03-23T18:15:22.000Z        Manchester    NH        Manchester  03101
# 2   2023-03-19T12:13:16.000Z              None  None              None   None
# 3   2023-03-14T16:20:51.000Z           Atlanta    GA           Atlanta  30313
# 4   2023-03-17T12:10:45.000Z         Arlington    VA         Arlington  22201
# 5   2023-03-03T22:22:19.000Z         Hawthorne    CA         Hawthorne  90250
# 6   2023-02-17T21:03:00.000Z         Melbourne    FL         Melbourne  32901
# 7   2022-11-22T20:32:25.000Z            Dallas    TX            Dallas  75201
# 8   2023-03-01T17:28:38.000Z            Irving    TX            Irving  75014
# 9   2023-03-16T00:23:03.000Z         Blacklick    OH         Blacklick  43004
# 10  2023-03-16T00:23:03.000Z  MIDDLE CITY EAST    PA  MIDDLE CITY EAST  20001
# 11  2023-03-16T00:23:03.000Z        Heidelberg    PA        Heidelberg  17088
# 12  2023-01-31T01:17:19.000Z      Philadelphia    PA      Philadelphia  19019
# 13  2023-03-16T00:01:50.000Z            Remote  None            Remote   None
# 14  2023-03-18T00:06:36.000Z        GREENVILLE    SC        GREENVILLE  29602
# 15  2023-03-23T21:48:23.000Z           Chicago    IL           Chicago  60642
# 16  2023-03-17T16:05:21.000Z              None  None              None   None
# 17  2022-12-03T21:01:01.000Z            Dallas    TX            Dallas  75260
# 18  2023-03-20T22:11:49.000Z         Pensacola    FL         Pensacola  32501
# 19  2023-03-20T22:11:49.000Z            Vienna    VA            Vienna  22180
#
#     remote
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# 10   False
# 11   False
# 12   False
# 13    True
# 14   False
# 15   False
# 16    True
# 17   False
# 18   False
# 19   False

# %%
greenhouse_df
# Out:
# Index([], dtype='object')
