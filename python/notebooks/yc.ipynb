# %%
import requests
from bs4 import BeautifulSoup
import undetected_chromedriver as uc
from time import sleep
from urllib.parse import urlencode, urljoin
import datetime
import json
import re
import pandas as pd

# %%
driver = uc.Chrome()

# %%
def get_companies():
    
    driver.get('https://www.ycombinator.com/companies?isHiring=true')
    sleep(10)
    page_len = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")

    while(True):
            last_len = page_len
            sleep(1)
            page_len= driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
            if last_len==page_len:
                break

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    results_div = soup.find('div', ['UzdOssTgtlpjmaMUbghW'])
    companies_a = results_div.find_all('a', class_='WxyYeI15LZ5U_DOM0z8F')
    companies_a[0]['href'].split('/')[-1]

    companies = [company['href'].split('/')[-1] for company in companies_a ]
    
    return companies

# %%
def get_location(locations) -> list:
    points = []
    for location in locations:
        if re.search('remote|anywhere|everywhere', location.strip().lower()):
            continue
        try:
            res = requests.get(
                f'https://geocode.maps.co/search?q={location}')
            sleep(0.6)
        except:
            continue
        try:
            data = res.json()[0]
        except:
            continue
        coordinates = [float(data.get('lon')), float(data.get('lat'))]
        points.append(coordinates)
    if points:
        return {'type': 'MultiPoint', 'coordinates': points}
    return None

# %%
def get_job_details(companies):
    base = 'https://www.ycombinator.com/'
    html_re = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')

    roles = {'developer', 'engineer', 'developers', 'engineers',  'data', 'analyst', 'scientist', 'frontend', 'software',
         'apprentice', 'apprenticeship', 'front-end', 'backend', 'back-end', 'intern', 'internship','fellowship'}

# Includes 'software' for titles that are just 'software engineer', etc.
    levels = {'junior', 'entry-level', 'grad', 'graduate', 'apprentice', 'web',
            'apprenticeship','fellowship', 'software', 'entry', 'intern', 'i', '1', 'associate', 'jr.', 'jr', 'cloud'}

    # Optional, but helps exclude higher level positions
    exclude = {'senior', 'principal', 'sr.', 'sr', 'ii', 'iii'}

    criteria = {'roles': roles, 'levels': levels, 'exclude': exclude}

    exp_levels = {'1+ years', 'any (new grads ok)', 'any'}
    jobs_data = []

    # company = 'wanderlog'

    # print(company)

    for company in companies:
        print(urljoin(base, f'companies/{company}/jobs'))
        driver.get(urljoin(base, f'companies/{company}/jobs'))
        html = driver.page_source

      
        bowl = BeautifulSoup(html, 'html.parser')
      
        try:
            job_count = bowl.find('span', class_ = 'ycdc-badge ml-0 font-bold no-underline').text
        except:
            continue

        if int(job_count) == 0:
            continue


        jobs = bowl.find(
            'div', class_="flex w-full flex-col justify-between divide-y divide-gray-200")

        
        
        for job in jobs:
            job_title = job.find('div', class_='ycdc-with-link-color').text

            title = set(job_title.lower().split())

            job_exp = job.find_all('div', class_='list-item')[-1].text
            exp_set = {job_exp.lower()}


            if title.intersection(roles) and not title.intersection(exclude) and exp_set.intersection(exp_levels) :
                print(job_title)
                job_link = job.find('a')['href']
                print(job_link)
                driver.get(urljoin(base, job_link))
                html = driver.page_source 
                cup = BeautifulSoup(html, 'html.parser')
                job_json = cup.find('script', attrs={'type': 'application/ld+json'})
                if not job_json:
                    continue
                job_dict = json.loads(job_json.text)
                print(job_dict.keys())

                job_datePosted = job_dict['datePosted']

                job_link = urljoin(base, job_link)
                job_company = job_dict['hiringOrganization'].get('name')

                job_description = cup.find(
                    'h2', class_='ycdc-section-title').next_sibling.text

                job_locations = []

                
                if job_dict.get('jobLocationType') == "TELECOMMUTE":
                    remote = True
                    job_locations.append(
                        f"Remote {job_dict.get('applicantLocationRequirements').get('name')}")
                else:
                    remote = False
    
                locations = job_dict.get('jobLocation')
                if locations:
                    for location in job_dict.get('jobLocation'):

                        address = location.get('address')

                        if type(address) is dict:
                            city = address.get('addressLocality')
                            state = address.get('addressRegion')
                            country = address.get('addressCountry')
                            job_locations.append(f'{city}, {state}, {country}')
                    
                print(job_locations)


                job_info = {'title': job_title, 'company': job_company, 'link': job_link,
                            'description': re.sub(html_re, '', job_description), 'date': datetime.datetime.fromisoformat(job_datePosted),
                            'source': 'yc', 'location': job_locations, 'points': get_location(job_locations), 'remote': remote, 'experience' : job_exp}
                jobs_data.append(job_info)
    return jobs_data

# %%
companies = get_companies()
len(companies)
# Out:
# 960

# %%
jobs = get_job_details(companies)
len(jobs)
# Out:
# https://www.ycombinator.com/companies/doordash/jobs
# Software Engineer, Distributed Databases
# /companies/doordash/jobs/Zfq9BV9-software-engineer-distributed-databases
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'jobLocationType', 'applicantLocationRequirements'])
# ['Remote US']
# https://www.ycombinator.com/companies/ginkgo-bioworks/jobs
# Computational Protein Engineer
# /companies/ginkgo-bioworks/jobs/BNlbYBV-computational-protein-engineer
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'baseSalary', 'jobLocation'])
# ['Boston, Massachusetts, US']
# https://www.ycombinator.com/companies/amplitude/jobs
# https://www.ycombinator.com/companies/stripe/jobs
# https://www.ycombinator.com/companies/instacart/jobs
# https://www.ycombinator.com/companies/opensea/jobs
# https://www.ycombinator.com/companies/faire/jobs
# https://www.ycombinator.com/companies/brex/jobs
# https://www.ycombinator.com/companies/deel/jobs
# https://www.ycombinator.com/companies/rippling/jobs
# https://www.ycombinator.com/companies/gusto/jobs
# https://www.ycombinator.com/companies/flexport/jobs
# https://www.ycombinator.com/companies/razorpay/jobs
# https://www.ycombinator.com/companies/scale-ai/jobs
# https://www.ycombinator.com/companies/rappi/jobs
# https://www.ycombinator.com/companies/checkr/jobs
# https://www.ycombinator.com/companies/meesho/jobs
# https://www.ycombinator.com/companies/relativity-space/jobs
# https://www.ycombinator.com/companies/webflow/jobs
# https://www.ycombinator.com/companies/whatnot/jobs
# https://www.ycombinator.com/companies/flock-safety/jobs
# https://www.ycombinator.com/companies/equipmentshare/jobs
# https://www.ycombinator.com/companies/goat-group/jobs
# https://www.ycombinator.com/companies/retool/jobs
# https://www.ycombinator.com/companies/grubmarket/jobs
# Quality Assurance Analyst
# /companies/grubmarket/jobs/vAhywVC-quality-assurance-analyst
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'jobLocationType', 'applicantLocationRequirements'])
# ['Remote US']
# https://www.ycombinator.com/companies/ironclad/jobs
# https://www.ycombinator.com/companies/xendit/jobs
# https://www.ycombinator.com/companies/groww/jobs
# Software Developer
# /companies/groww/jobs/HNb92j9if-software-developer
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'jobLocation'])
# ['Bengaluru, Karnataka, IN']
# React Native Developer
# /companies/groww/jobs/ensP1UwH0-react-native-developer
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'jobL
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'baseSalary', 'jobLocationType', 'applicantLocationRequirements'])
# ['Remote US']
# https://www.ycombinator.com/companies/dyneti-technologies/jobs
# Software Engineer (Android)
# /companies/dyneti-technologies/jobs/WRoj583ad-software-engineer-android
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'baseSalary', 'jobLocation'])
# ['San Francisco, California, US']
# Software Engineer (iOS)
# /companies/dyneti-technologies/jobs/kYDOhyd06-software-engineer-ios
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'baseSalary', 'jobLocation'])
# ['San Francisco, California, US']
# Deep Learning Engineer
# /companies/dyneti-technologies/jobs/CXrJoyA97-deep-learning-engineer
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'jobLocation'])
# ['San Francisco, California, US']
# https://www.ycombinator.com/companies/sorting-robotics/jobs
# Robots! Software Developer
# /companies/sorting-robotics/jobs/fv9H7oe-robots-software-developer
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'baseSalary', 'jobLocation'])
# ['Los Angeles, California, US']
# https://www.ycombinator.com/companies/the-juggernaut/jobs
# https://www.ycombinator.com/companies/parker/jobs
# Founding Engineer
# /companies/parker/jobs/DB6cu2B-founding-engineer
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'baseSalary', 'jobLocation', 'jobLocationType', 'applicantLocationRequirements'])
# ['Remote US', 'New York, New York, US']
# https://www.ycombinator.com/companies/flockjay/jobs
# https://www.ycombinator.com/companies/trexo-robotics/jobs
# Android Developer
# /companies/trexo-robotics/jobs/qbW5KeK-android-developer
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'baseSalary', 'jobLocation', 'jobLocationType', 'applicantLocationRequirements'])
# ['Remote CA', 'Mississauga, Ontario, CA']
# https://www.ycombinator.com/companies/overview/jobs
# Manufacturing Applications Engineer
# /companies/overview/jobs/KRPlCgu-manufacturing-applications-engineer
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'jobLocation', 'jobLocationType', 'applicantLocationRequirements'])
# ['Remote US', 'San Francisco, California, US']
# Full Stack Engineer
# /companies/overview/jobs/uCHykci-full-stack-engineer
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'baseSalary', 'jobLocation'])
# ['San Francisco, California, US']
# Frontend / Full Stack Engineer
# /companies/overview/jobs/vhfKmA1-frontend-full-stack-engineer
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'baseSalary', 'jobLocation'])
# ['San Francisco, California, US']
# Applied Computer Vision / Deep Learning Engineer
# /companies/overview/jobs/NTETdxf-applied-computer-vision-deep-learning-engineer
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'baseSalary', 'jobLocation'])
# ['San Francisco, California, US']
# https://www.ycombinator.com/companies/imgix/jobs
# https://www.ycombinator.com/companies/qvin/jobs
# https://www.ycombinator.com/companies/mixrank/jobs
# Software Engineer - Global/Remote
# /companies/mixrank/jobs/35HrJ61-software-engineer-global-remote
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'baseSalary', 'jobLocationType', 'applicantLocationRequirements'])
# ['Remote US']
# Full-Stack Web Developer  - Global/Remote
# /companies/mixrank/jobs/TXvOcDb-full-stack-web-developer-global-remote
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'baseSalary', 'jobLocationType', 'applicantLocationRequirements'])
# ['Remote US']
# Data Engineer - Global/Remote
# /companies/mixrank/jobs/SaoXMWj-data-engineer-global-remote
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'baseSalary', 'jobLocationType', 'applicantLocationRequirements'])
# ['Remote US']
# Junior Software Engineer - Global/Remote
# /companies/mixrank/jobs/WdgITmW-junior-software-engineer-global-remote
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'baseSalary', 'jobLocationType', 'applicantLocationRequirements'])
# ['Remote US']
# https://www.ycombinator.com/companies/zenysis/jobs
# Software Engineer
# /companies/zenysis/jobs/iw3MkR8hl-software-engineer
# dict_keys(['@context', '@type', 'title', 'url', 'description', 'datePosted', 'employmentType', 'hiringOrganization', 'baseSalary', 'jobLocation'])
# ['San Francisco, California, US']
# https://www.ycombinator.com/companies/bonsai/jobs
# https://www.ycombinator.com/companies/golorry/jobs
# https://www.ycombinator.com/companies/plato/jobs
# https://www.ycombinator.com/companies/thunkable/jobs
# https://www.ycombinator.com/companies/castle-2/jobs
# https://www.ycombinator.com/companies/measurable-ai-mailtime/jobs
# https://www.ycombinator.com/companies/pocketsuite/jobs
# https://www.ycombinator.com/companies/gigwell/jobs
# https://www.ycombinator.com/companies/the-muse/jobs
# 288

# %%
jobs_df = pd.DataFrame.from_records(jobs)
jobs_df
# Out:
#                                          title          company  \
# 0     Software Engineer, Distributed Databases         DoorDash
# 1               Computational Protein Engineer  Ginkgo Bioworks
# 2                    Quality Assurance Analyst       GrubMarket
# 3                          Software Developer             Groww
# 4                       React Native Developer            Groww
# ..                                         ...              ...
# 283          Software Engineer - Global/Remote          MixRank
# 284  Full-Stack Web Developer  - Global/Remote          MixRank
# 285              Data Engineer - Global/Remote          MixRank
# 286   Junior Software Engineer - Global/Remote          MixRank
# 287                          Software Engineer          Zenysis
#
#                                                   link  \
# 0    https://www.ycombinator.com/companies/doordash...
# 1    https://www.ycombinator.com/companies/ginkgo-b...
# 2    https://www.ycombinator.com/companies/grubmark...
# 3    https://www.ycombinator.com/companies/groww/jo...
# 4    https://www.ycombinator.com/companies/groww/jo...
# ..                                                 ...
# 283  https://www.ycombinator.com/companies/mixrank/...
# 284  https://www.ycombinator.com/companies/mixrank/...
# 285  https://www.ycombinator.com/companies/mixrank/...
# 286  https://www.ycombinator.com/companies/mixrank/...
# 287  https://www.ycombinator.com/companies/zenysis/...
#
#                                            description  \
# 0    About the Team\nThe mission of the Database an...
# 1    Our mission is to make biology easier to engin...
# 2    GrubMarket is a disruptive food tech company t...
# 3    As a Software Engineer at Groww, you will be w...
# 4    We are looking for a great JavaScript develope...
# ..                                                 ...
# 283  MixRank processes petabytes of data every mont...
# 284  At MixRank, we create B2B SaaS products that e...
# 285  At MixRank, we create B2B SaaS products that e...
# 286  At MixRank, we create B2B SaaS products that e...
# 287  Zenysis builds software for developing nations...
#
#                          date source                         location  \
# 0   2021-09-28 04:05:33+00:00     yc                      [Remote US]
# 1   2023-06-07 18:28:57+00:00     yc      [Boston, Massachusetts, US]
# 2   2022-03-01 05:59:31+00:00     yc                      [Remote US]
# 3   2019-03-26 12:54:24+00:00     yc       [Bengaluru, Karnataka, IN]
# 4   2018-07-25 20:12:33+00:00     yc       [Bengaluru, Karnataka, IN]
# ..                        ...    ...                              ...
# 283 2022-09-01 16:06:14+00:00     yc                      [Remote US]
# 284 2021-12-17 10:15:30+00:00     yc                      [Remote US]
# 285 2021-12-17 10:12:20+00:00     yc                      [Remote US]
# 286 2021-12-17 10:08:38+00:00     yc                      [Remote US]
# 287 2018-08-16 18:23:01+00:00     yc  [San Francisco, California, US]
#
#                                                 points  remote  \
# 0                                                 None    True
# 1    {'type': 'MultiPoint', 'coordinates': [[-71.05...   False
# 2                                                 None    True
# 3    {'type': 'MultiPoint', 'coordinates': [[77.590...   False
# 4    {'type': 'MultiPoint', 'coordinates': [[77.590...   False
# ..                                                 ...     ...
# 283                                               None    True
# 284                                               None    True
# 285                                               None    True
# 286                                               None    True
# 287  {'type': 'MultiPoint', 'coordinates': [[-122.4...   False
#
#              experience
# 0              1+ years
# 1    Any (new grads ok)
# 2              1+ years
# 3    Any (new grads ok)
# 4    Any (new grads ok)
# ..                  ...
# 283  Any (new grads ok)
# 284  Any (new grads ok)
# 285  Any (new grads ok)
# 286  Any (new grads ok)
# 287            1+ years
#
# [288 rows x 10 columns]
