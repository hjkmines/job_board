# %%
from bs4 import BeautifulSoup
from time import sleep
import requests
import undetected_chromedriver as uc
from urllib.parse import urljoin, urlencode
import re
import json
from datetime import datetime


def scrape_dice(query="junior software developer", pages=1, wait=5):

    with open('./zipUS.json', 'r') as f:
        zip_coords = json.load(f)

    base = 'https://www.dice.com/jobs/'
    params = {}
    params['q'] = query

    titles = []
    companies = []
    links = []
    remote = []

    cities = []
    states = []
    countries = []
    zips = []
    points = []
    dates = []
    raw_dates = []
    descriptions = []

    def scrap_template1(cup):

        description = cup.find('div', id='jobdescSec')
        scripts = cup.find_all('script', type="text/javascript")
        job_info = scripts[4]
        json_txt = re.search(r'"jobId(.|\n)*}', job_info.text)
        json_txt_clean = re.sub(r'//.*', '', json_txt.group())
        json_txt_clean = "{"+json_txt_clean
        job_json = json.loads(json_txt_clean)
        job_json['description'] = description.text

        try:
            company = cup.find('span', id='hiringOrganizationName')
            companies.append(company.text)
        except:
            companies.append(None)

        try:
            description = cup.find('div', id='jobdescSec')
            descriptions.append(description.text)
        except:
            descriptions.append(None)

        try:
            scripts = cup.find_all('script', type="text/javascript")
            job_info = scripts[4]
            json_txt = re.search(r'"jobId(.|\n)*}', job_info.text)
            json_txt_clean = re.sub(r'//.*', '', json_txt.group())
            json_txt_clean = "{"+json_txt_clean
            job_json = json.loads(json_txt_clean)
            cities.append(job_json['jobCity'])
            states.append(job_json['jobRegion'])
            countries.append(job_json['jobCountry'])
            zip_code = job_json.get('jobPostalCode')
            zips.append(job_json['jobPostalCode'])
            dates.append(job_json['datePosted'])
            raw_dates.append(job_json['datePosted'])
            remote.append(job_json['remote'])

            if zip_code:
                coordinates = [float(zip_coords[str(zip_code)]
                               ['LONG']), float(zip_coords[str(zip_code)]['LAT'])]
                points.append(
                    {'type': 'MultiPoint', 'coordinates': [coordinates]})
            else:
                points.append(None)

        except:
            dates.append(None)
            raw_dates.append(None)
            cities.append(None)
            states.append(None)
            zips.append(None)
            points.append(None)
            countries.append(None)
            remote.append(None)

    def scrap_template2(cup):
        try:
            description = cup.find('div', id='jobDescription')
            descriptions.append(description.text)
        except:
            descriptions.append(None)

        try:
            company = cup.find('a', attrs={'data-cy': 'companyNameLink'})
            if not company:
                company = cup.find('a', attrs={'data-cy': 'companyNameNoLink'})
            companies.append(company.text)
        except:
            companies.append(None)

        try:
            json_text = cup.find('script', id="__NEXT_DATA__")
            jobdic = json.loads(json_text.text)
            jobdata = jobdic['props']['pageProps']['initialState']['api']['queries']
            firstkey = list(jobdata.keys())[0]
            locationdetail = jobdata[firstkey]['data']['locationDetail']
            locationdata = locationdetail['locations'][0]
            dateposted = jobdata[firstkey]['data']['datePosted']
            dateposted = datetime.fromisoformat(dateposted)

            dates.append(dateposted)

            raw_dates.append(jobdata[firstkey]['data']['datePosted'])
            remote_status = locationdetail['remote']
            remote.append(remote_status)
            cities.append(locationdata['city'])
            countries.append(locationdata['country'])
            states.append(locationdata['state'])
            zip_code = locationdata.get('postalCode')
            zips.append(locationdata['postalCode'])

            if zip_code:
                coordinates = [float(zip_coords[str(zip_code)]
                               ['LONG']), float(zip_coords[str(zip_code)]['LAT'])]
                points.append(
                    {'type': 'MultiPoint', 'coordinates': [coordinates]})
            else:
                points.append(None)
        except:
            dates.append(None)
            raw_dates.append(None)
            cities.append(None)
            states.append(None)
            zips.append(None)
            points.append(None)
            remote.append(None)
            countries.append(None)

    def get_location(zip: str):
        try:
            res = requests.get(f'https://geocode.maps.co/search?q={zip},USA')
            sleep(0.55)
        except:
            return None
        data = res.json()[0]
        coordinates = [float(data.get('lon')), float(data.get('lat'))]
        if coordinates:
            return {'type': 'MultiPoint', 'coordinates': [coordinates]}
        return None

    def scrap_job(joblink):
        res = requests.get(joblink)
        cup = BeautifulSoup(res.text, 'html.parser')

        if cup.find('div', id='jobdescSec'):
            scrap_template1(cup)
        else:
            scrap_template2(cup)
    # web driver setup
    driver = uc.Chrome()

    for page in range(1, pages+1):
        url = base + urlencode(params).replace('=', '-')+f'-jobs?p={page}'
        driver.get(url)
        sleep(wait)
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        # parent container for job cards
        jobs_list = soup.find('div', attrs={'id': 'search-results-control'})
        jobs = jobs_list.find_all('h3')
        job_titles = [title.find('span').text for title in jobs]
        job_links = [urljoin(base, job.find('a')['href']) for job in jobs]
        jobs_list.find_all('span', class_='compName')
        titles += job_titles
        links += job_links

    for link in links:
        scrap_job(link)

    driver.close()

    # df = pd.DataFrame()
    # df['title'] = titles
    # df['company'] = companies
    # df['link'] = links
    # df['description'] = descriptions
    # df['date'] = dates
    # df['raw_date'] = raw_dates
    # df['country'] = countries
    # df['state'] = states
    # df['city'] = cities
    # df['zip'] = zips
    # df['remote'] = remote
    # df['points'] = points
    # df['source'] = 'dice'

    data = []

    for i in range(len(titles)):
        if descriptions[i]:
            job_data = {'title': titles[i],
                        'company': companies[i],
                        'link': links[i],
                        'description': descriptions[i],
                        'date': dates[i],
                        'raw_date': raw_dates[i],
                        'city': cities[i],
                        'state': states[i],
                        'country': countries[i],
                        'zip': zips[i],
                        'points': points[i],
                        'remote': remote[i],
                        'source': 'dice',
                        }

            data.append(job_data)

    return data

# %%
# Out:
# [{'title': 'Junior Software Engineer',
#   'company': 'CGI',
#   'link': 'https://www.dice.com/jobs/detail/Junior-Software-Engineer-CGI-Lafayette-LA-70501/cgiamsbot/2185_J0423%26%23450297',
#   'description': 'Junior Software Engineer  Position Description  The successful candidate will have experience within an agile environment (preferably SAFe Agile) and will have experience with a combination of back end and front-end development utilizing some of the following technologies:• Java• Docker, Kubernetes, AWS• Postgres, Spring boot, Cloud Foundry, Restful services• Eureka, Kibana, ActiveMQ, IntelliJ, Jenkins technical environment.• typescript, nodejs, twitter bootstrap• Nice to have: Python, Ruby, AngularLooking for the following qualities:• Resourcefulness - ability and desire to dig in to solve problems,• Aptitude and willingness to learn and grow while having fun on a dynamic team,• Excellent communication skills and ability to communicate clearly with clients and team members in other locations,• Leadership - ability to provide leadership within the team,• Personable and able to have a laugh while being focused to work towards deadlines.Responsibilities will include:• Pointing user stories• Working within scrum teams consisting of PO, SM, other engineers, and testers• Understanding requirements within user stories• Owning user stories and working independently• Troubleshooting and working within a team structure of 5 - 10 team members• Unit testing work• Ability to do more complex testing on user stories (that you didn\'t code) when the team needs to swarm at end of sprint• Deploying into a pipeline• Being client-facing, so excellent written and verbal communication• Raising and mitigating risks within a team• Overcoming issues - resourcefulness!Excellent verbal and written communication skills are a must.Required qualification to be successful in this role:- Agile/Scrum experience- 2 years Java experience, Docker, Kubernetes, AWS, Spring, Restful Services, Javascript, Javascript frameworks.Postgres, Spring boot, Cloud Foundry, Restful services, Eureka, Kibana, ActiveMQ, IntelliJ, Jenkins, typescript, nodejs, twitter bootstrap- 2+ years of SW engineering- Analytical skills: Detail oriented with ability to critically evaluate information gathered from multiple sources, reconcile conflicts, decompose high-level information into details, abstract up from low-level information to a more general understanding, distinguish presented user requests from the underlying true needs, and distinguish solution ideas from requirements.- Organizational skills: Ability to work with the information gathered during requirements analysis and to exercise flexibility with changing business priorities- Interpersonal skills: Must be able to help negotiate priorities and to resolve conflicts among representatives from various business and development teams- Team skills: Works will with others, delivers positive energy to their teamTime Management skills: Ability to work in a fast-paced team environment and consistently meet deadlines and work independently with minimal supervisionCGI is required by law in some jurisdictions to include a reasonable estimate of the compensation range for this role. The determination of this range includes various factors not limited to skill set, level, experience, relevant training, and licensure and certifications. To support the ability to reward for merit-based performance, CGI typically does not hire individuals at or near the top of the range for their role. Compensation decisions are dependent on the facts and circumstances of each case. A reasonable estimate of the current range for this role in the U.S. is $ 67,000-146,900 #CGIFederalJob#Dice#LI-AD1Your future duties and responsibilitiesRequired qualifications to be successful in this roleInsights you can act onWhile technology is at the heart of our clients\' digital transformation, we understand that people are at the heart of business success. When you join CGI, you become a trusted advisor, collaborating with colleagues and clients to bring forward actionable insights that deliver meaningful and sustainable outcomes. We call our employees "m ...
#   'date': datetime.datetime(2023, 4, 6, 8, 2, 39),
#   'raw_date': '2023-04-06T08:02:39.000Z',
#   'city': 'Lafayette',
#   'state': 'LA',
#   'country': 'US',
#   'zip': '70501',
#   'points': {'type': 'MultiPoint', 'coordinates': [[-91.991039, 30.241832]]},
#   'remote': False,
#   'source': 'dice'},
#  {'title': 'Junior Software Developer',
#   'company': 'Booz Allen Hamilton',
#   'link': 'https://www.dice.com/jobs/detail/Junior-Software-Developer-Booz-Allen-Hamilton---/booz/R0162376',
#   'description': "Job Number: R0162376 Software Developer, JuniorThe Challenge:Do you want to build sof tware that solves enterprise-scale challenges while learning and growing your skills?This role is more than just coding. Our junior developers use their passion to learn new tools and te chn iques and apply them towards identifying and delivering needed sof tware solutions. You will learn sof tware development principles and how to apply them through various development methodologies, including Scrum, Scaled Agile Framework, and Kanban. Our goal in hiring a junior developer is to match your intensity and passion for sof tware development with our deep experience in the practice of sof tware delivery to help deliver products for our customers and to evolve your career.Join us. The world can't wait.You Have:Experience with Java, Python, and JavaScript in industry or academic environmentsExperience with researching, designing, developing, or modifying enterprise-wide systems or applications sof tware in an internship or academic environmentKnowledge of Web protocols and servicesAbility to work independently and within a team Ability to obtain a security clearance HS diploma or GEDNice If You Have:Experience with Agile sof tware development processes and tools, including Atlassian Tool SuiteExperience with documenting testing and maintenance of system correctionsKnowledge of Oracle or MS Structured Query LanguagePossession of excellent analysis and problem solving skillsBachelor's degreeClearance: Applicants selected will be subject to a security investigation and may need to meet eligibility requirements for access to classified information .Build Your Career:A challenging and dynamic work environment isn't all we have to offer. When you join Booz Allen, you'll have access to:experts in virtually every fielda culture that focuses on supporting our employeesopportunities that provide stability while offering varietyYou'll also be exposed to a wealth of training resources through our Digital University, an online learning portal featuring more than 5000 functional and te chn ical courses, certifications, and books. Build your te chn ical skills through hands-on training on the latest tools and tech from our in-house experts. Pursuing certifications that directly impact your role? You may be able to take advantage of our tuition assistance, on-site boot camps, certification training, academic programs, vendor relationships, and a network of professionals who can give you helpful tips. We'll help you develop the career you want as you chart your own course for success.CompensationAt Booz Allen, we celebrate your contributions, provide you with opportunities and choices, and support your total well-being. Our offerings include health, life, disability, financial, and retirement benefits, as well as paid leave, professional development, tuition assistance, work-life programs, and dependent care. Our recognition awards program acknowledges employees for exceptional performance and superior demonstration of our values. Full-time and part-time employees working at least 20 hours a week on a regular basis are eligible to participate in Booz Allen's benefit programs. Individuals that do not meet the threshold are only eligible for select offerings, not inclusive of health benefits. We encourage you to learn more about our total benefits by visiting the Resource page on our Careers site and reviewing Our Employee Benefits page.Salary at Booz Allen is determined by various factors, including but not limited to location, the individual's particular combination of education, knowledge, skills, competencies, and experience, as well as contract-specific affordability and organizational requirements. The projected compensation range for this position is $49,900.00 to $102,000.00 (annualized USD). The estimate displayed represents the typical salary range for this position and is just one component of Booz Allen's total compensation package for e ...
#   'date': datetime.datetime(2023, 5, 3, 9, 34, 21),
#   'raw_date': '2023-05-03T09:34:21.000Z',
#   'city': None,
#   'state': None,
#   'country': None,
#   'zip': None,
#   'points': None,
#   'remote': True,
#   'source': 'dice'},
#  {'title': 'Junior Software Developer',
#   'company': None,
#   'link': 'https://www.dice.com/jobs/detail/Junior-Software-Developer-Kantar-Linden-PA-17744/appblok/16164_R077426',
#   'description': 'We\'re the world\'s leading data, insights, and consulting company; we shape the brands of tomorrow by better understanding people everywhere.  Our Functions teams are right at the centre of our business, making sure we can always get better, every day. Supporting the business with things like Marketing, Human Resources, Finance, Legal and Technology, our Functions colleagues are skilled professionals whose role it is to ensure we continue to become an indispensable partner to brands everywhere. Job Details Title: Junior Software DeveloperLocation: RemoteIt\'s time for a new vision of ad intelligence. Vivvix unifies the advertising intelligence businesses of Kantar and Numerator into an independent company built for innovation, focused on delivering winning clarity for our clients to drive smarter, faster, better decisions. Our vision is to help anyone understand their competitive landscape and view all the dimensions of advertising that might go unseen.At Vivvix, we have three powerful tenets. We help clients build up a greater understanding of your competitive landscape. We level up advertisers, agencies, and media owners to take command over competitors. We enable them to power up and chart a winning path for themselves.Pitch in to the building of the SMART tech platform at AdIntel. SMART platform is used by advertisers for creative ad tracking and ad spend monitoring across 23 traditional and digital media channels.Responsibilities:Lead the scrum teams.Own and deliver a high impact roadmap that will delight customers.Prioritise features, bugs and tech debts.Contribute in making platform stable and performant.Contribute to a culture of technical excellence.Lead the ways of working and have a data first approach.Build trust and lead the relationships with various partners across engineering, business,product, design and analytics teams.Hire, mentor and provide a career growth path for the team.Innovate, solve business problems and have a bias for action.Requirements:3+ years of software development experience.Excellent technical skills having strong Java background.BE/BTech or higher degree in Computer Science/Engineering or equivalent experience.Strong communication skills to collaborate with technical and non-technical team members.Hands-on expertise in Java, SpringBoot, Apache SOLR, MongoDBExpertise on handling large volume of data is a plus.Should have expertise in AWS cloud platform.Should be very strong in system design.Having SAAS product building experience is a plus.BenefitsWe provide a comprehensive, highly competitive benefits package, includingMedical plans with comprehensive, affordable coverage for a range of health servicesHealth Savings Account/FSADental, Vision and benefits to cover unique healthcare needsWellness Program401k with matchingTuition Reimbursement, Commuter benefitsUnlimited PTOAt Kantar we have an integrated way of rewarding our people based around a simple, clear and consistent set of principles. Our approach helps to ensure we are market competitive and to support a pay for performance culture, where your reward and career progression opportunities are linked to what you deliver. We go beyond the obvious, using intelligence, passion and creativity to inspire new thinking and shape the world we live in. Apply for a career that\'s out of the ordinary and join us. We want to create an equality of opportunity in a fair and supportive working environment where people feel included, accepted, and are allowed to flourish in a space where their mental health and wellbeing is taken into consideration. We want to create a more diverse community to expand our talent pool, be locally representative, drive diversity of thinking and better commercial outcomes.At Kantar, the diversity of our employees provides a richer environment for our employees and broader depth and breadth of thinking for our clients. Kantar is committed to inclusion and diversity; therefore, we welcome applications f ...
#   'date': datetime.datetime(2023, 5, 31, 1, 2, 11),
#   'raw_date': '2023-05-31T01:02:11.000Z',
#   'city': 'Linden',
#   'state': 'PA',
#   'country': 'US',
#   'zip': '17744',
#   'points': {'type': 'MultiPoint', 'coordinates': [[-77.153274, 41.24097]]},
#   'remote': False,
#   'source': 'dice'},
#  {'title': 'Jr. Software Engineer- Embedded',
#   'company': 'ConsultNet, LLC',
#   'link': 'https://www.dice.com/jobs/detail/Jr.-Software-Engineer%26%2345-Embedded-ConsultNet%2C-LLC-Hawthorne-CA-90250/cxcnetut/23%26%234500408',
#   'description': "Job DescriptionJr. Software Engineer- Embedded Hawthorne, CA Direct Hire $80- $90K year  Immediate hire with growing company. Will be responsible for embedded systems and kernel development. Developing device drivers and embedded firmware. Application performance tuning, debugging, testing and supporting software releases. Works as part of an integrated product team using Agile development methodology  Required Skills:  C++ knowledge and experience  C knowledge and experience  OO programming in C++  Multithreaded systems knowledge  College degree with good GPA  Good communicator  Willing to go to office every day (reasonable commute distance)  Bonus Skills:  Familiarity with FPGA design and integration is a plus  Previous Agile development experience is a plus  Experience with GPIO, SPI and Serial Communication on ARM processors is a plus     Be a part of the ConsultNet difference. As a leading national provider of IT staffing and solutions, ConsultNet delivers exceptional services to startup, midmarket and Fortune 1000 companies across North America. Since 1996, we've partnered with clients to create rewarding opportunities for our consultants, successfully building teams that have surefire results.   In the past two years alone, we have placed more than 1,500 consultants in contract, contract-to-hire, or direct placement opportunities. We understand communication is key to finding the right job that matches your skills and career goals. For us, it's not just the work that we do; it's how we do the work. Our breadth of offerings extends to multiple IT positions in major markets throughout the country, see more at -Report this jobDice Id: ConsultNet, LLCPosition Id: 23-00408",
#   'date': datetime.datetime(2023, 3, 3, 22, 22, 19),
#   'raw_date': '2023-03-03T22:22:19.000Z',
#   'city': 'Hawthorne',
#   'state': 'CA',
#   'country': 'US',
#   'zip': '90250',
#   'points': {'type': 'MultiPoint', 'coordinates': [[-118.348083, 33.914775]]},
#   'remote': False,
#   'source': 'dice'},
#  {'title': 'Junior Software Engineer',
#   'company': 'Comrise',
#   'link': 'https://www.dice.com/jobs/detail/Junior-Software-Engineer-Comrise-Warren-NJ-07059/comrise/7914022',
#   'description': 'Job Title: Junior Software Engineer (Operations Analyst)Location: Warren, NJTerm: Perm/Full-Time/Direct-HireIndustry: Oil and GasSalary: $70k-80k/yrNote: No C2C/C2H/Visa Sponsorship\xa0Position Overview:We are currently in search of a highly motivated, team-oriented, and proactive Software Engineer / Operations Analyst. This position will be primarily responsible for designing and developing back-end services, database design and management for interfacing internal REST APIs, integration features, and supporting web applications as part of the back-office Customer Operations team.\xa0The position will collaborate with other teams including but not limited to supply, trading, finance, accounting, legal, credit, risk, and IT. The Software Engineer / Operations Analyst will report to the Director of Operations. The ideal candidate exhibits strong analytical skills, written and verbal skills, and works well under pressure.\xa0Key Responsibilities:Produce implementation plans for back-end projects and services.Optimize existing services with scalability and recyclability in mind.Create automated workflows triggered by application activity to match business logic expectations.Design internal REST API to supply interface capabilities to internal front-end apps and other third-party users.Develop documentation in parallel along with in depth study material for services were built.Automation and support of all back-office operations including but not limited to project management, reporting and analysis, metrics and KPIs, billing, onboarding, and commissions management.\xa0Qualifications:Bachelor s degree in mathematics, economics, business, engineering, or equivalent experience.2 years of experience preferably in an operations role with some exposure to customer onboarding, billing, and contract management.2+ years of experience in web development technologiesExperience with Node, JavaScript, and corresponding frameworks (Angular, React, Express, etc.)Experience with JS testing libraries such as Enzyme, Jest and JUnitKnowledge of web application technologies such as REST API, SOAP, GraphQL, JSONUnderstanding of relational databases such as PostgreSQL and various NoSQL databases (MongoDB, DynamoDB)Experience with Linux-based operating systems (Ubuntu, Amazon Linux, Mint, etc.), shell scripting, CRON jobs.Practical experience with serverless cloud suites like AWS Lambda, ECS, API Gateway, etc.Strong verbal and written communication skills.Excellent time management skills, ability to thrive in a fast-paced environment.Advanced level of proficiency in Microsoft Excel and other Office productsProven track record for process improvement.\xa0Benefits:Great work environment and great earning potential.Interaction with highly experienced and successful energy executives on a recurring basisThe opportunity to be a key contributor & to grow with the company as it rapidly expands.Medical, Dental, Vision, 401K, and other benefits.Report this jobDice Id: comrisePosition Id: 7914022',
#   'date': datetime.datetime(2023, 6, 1, 15, 45, 50),
#   'raw_date': '2023-06-01T15:45:50.000Z',
#   'city': 'Warren',
#   'state': 'NJ',
#   'country': 'US',
#   'zip': '07059',
#   'points': {'type': 'MultiPoint', 'coordinates': [[-74.519044, 40.634588]]},
#   'remote': False,
#   'source': 'dice'},
#  {'title': 'Junior Software Engineer at Top...',
#   'company': 'Motion Recruitment',
#   'link': 'https://www.dice.com/jobs/detail/Junior-Software-Engineer-at-Top-Industrial-Manufacturing-Industry-Motion-Recruitment-Beverly-MA-01915/10105282/551181',
#   'description': 'Job Description An Industrial Manufacturing company north of Boston is hiring a Junior Software Engineer to join their team. As a Junior Engineer you will be a part of a team of growing developers and assist in building out mission-critical applications for the company. This role is Hybrid to Beverly, MA, and is a direct hire. This position offers the opportunity to gain experience working on manufacturing applications in a full stack role. You will be developing on an internal application portal that is used by every employee at the company. This application supports the manufacturing of high precision gears that are used widely in medical devices, semiconductors, and even the defense space. The company is seeking a highly motivated to join the team. Required Skills & Experience  Highly skilled in C# and .NET Core development Skilled in working with Angular Exposure to working with SQL Understanding of Manufacturing processes  Desired Skills & Experience  Experience in the Manufacturing Industry 1+ years of developing experience Degree in computer science or a related field Strong technical skills  What You Will Be Doing Daily Responsibilities  100% Hands-On 50% Front-end and 50% Back-end  The Offer   Bonus OR Commission eligible  You will receive the following benefits  Medical Insurance Dental Benefits Vision Benefits Paid Time Off (PTO) 401(k) {including match - if applicable}    Applicants must be currently authorized to work in the US on a full-time basis now and in the future.Report this jobDice Id: 10105282Position Id: 551181',
#   'date': datetime.datetime(2023, 4, 8, 0, 16, 58),
#   'raw_date': '2023-04-08T00:16:58.000Z',
#   'city': 'Beverly',
#   'state': 'MA',
#   'country': 'US',
#   'zip': '01915',
#   'points': {'type': 'MultiPoint', 'coordinates': [[-70.867583, 42.570665]]},
#   'remote': False,
#   'source': 'dice'},
#  {'title': 'Junior Software Developer',
#   'company': 'Maximus',
#   'link': 'https://www.dice.com/jobs/detail/Junior-Software-Developer-Maximus-Remote--/RTL50274/2023%26%234589027',
#   'description': "We are seeking a Junior Software Developer to join our growing team. In this role, you will be responsible for developing, testing, and maintaining software applications. You will work closely with our DevOps engineers, data scientists, internal and external clients to assist with the development of software and applications that meet our internal and external customer needs. The ideal candidate will be innovative and develop solutions that integrate with current technologies on our internal and external cloud infrastructure with various database integrations. Understanding user interfaces (UI) and dashboards as well as being able to create them with Python, Java, HTML, and similar languages is a must.• Collaborate with cross-functional teams to identify software requirements and design solutions.• Develop, test, and deploy software applications.• Debug and troubleshoot software issues.• Maintain and improve existing software systems.• Write clean, efficient, and well-documented code (Python required).• Participate in code reviews and contribute to the development of coding standards.• Stay up to date with emerging technologies and industry trends.Required Skills (required skills that should be contract-driven, verifiable, and measurable):• ship Required• Bachelor's degree in computer science or related field• 1+ year(s) of experience in software development• Proficiency in one or more programming languages (Java, Python, C++, etc.).Desired/Preferred Skills (not contractual obligations):• Familiarity with software development tools such as IDEs, version control systems, and build tools• Strong problem-solving and analytical skills• Excellent communication and teamwork skills• Ability to work independently and take initiative#techjobs Job Summary Maximus TCS (Technology and Consulting Services) Internal Job Profile Code: TCS193, T1, Band 4 MAXIMUS Introduction Since 1975, Maximus has operated under its founding mission of Helping Government Serve the People, enabling citizens around the globe to successfully engage with their governments at all levels and across a variety of health and human services programs. Maximus delivers innovative business process management and technology solutions that contribute to improved outcomes for citizens and higher levels of productivity, accuracy, accountability and efficiency of government-sponsored programs. With more than 30,000 employees worldwide, Maximus is a proud partner to government agencies in the United States, Australia, Canada, Saudi Arabia, Singapore and the United Kingdom. For more information, visit  EEO Statement EEO Statement: Active military service members, their spouses, and veteran candidates often embody the core competencies Maximus deems essential, and bring a resiliency and dependability that greatly enhances our workforce. We recognize your unique skills and experiences, and want to provide you with a career path that allows you to continue making a difference for our country. We're proud of our connections to organizations dedicated to serving veterans and their families. If you are transitioning from military to civilian life, have prior service, are a retired veteran or a member of the National Guard or Reserves, or a spouse of an active military service member, we have challenging and rewarding career opportunities available for you. A committed and diverse workforce is our most important resource. Maximus is an Affirmative Action/Equal Opportunity Employer. Maximus provides equal employment opportunities to all qualified applicants without regard to race, color, religion, sex, sexual orientation, gender identity, national origin, protected veteran status or disabled status.  Pay Transparency Maximus compensation is based on various factors including but not limited to job location, a candidate's education, training, experience, expected quality and quantity of work, required travel (if any), external market and internal value analysis includi ...
#   'date': datetime.datetime(2023, 6, 3, 0, 2, 51),
#   'raw_date': '2023-06-03T00:02:51.000Z',
#   'city': 'Remote',
#   'state': None,
#   'country': 'US',
#   'zip': None,
#   'points': None,
#   'remote': True,
#   'source': 'dice'},
#  {'title': 'Junior Software Developer',
#   'company': 'Evoke Technologies',
#   'link': 'https://www.dice.com/jobs/detail/Junior-Software-Developer-Evoke-Technologies-Dallas-TX-75201/10124918/7676417',
#   'description': 'Position: Junior Software Developer Location: Plano, TexasDuration: Fulltime – Permanent\xa0Evoke Technologies is currently seeking multiple entry level software developers.You will be assisting our delivery team in enhancing and supporting current client or internal projects.You will be hands on working with our practice in the Business Process Management (BPM) space.All of the work that will be performed will be performed under the supervision and guidance of a Senior Developer.Potential candidates must be willing to participate in our 6–8-week training program that takes place at our state-of-the-art IT facility in Hyderabad, India.With this being stated, all candidates must have a valid passport or obtain one within two weeks of start date.\xa0Must have excellent organizational skills, attention to detail, and the ability to prioritize in a changing environment.Must have excellent interpersonal skills through different forms of communication and be able to follow up accordingly.Proficiency in Microsoft Word, Excel, and Outlook required.Ability to learn new software systems.Strong verbal and written communication skillsAbility to work independent and as part of a team.Exposure to object-oriented programming\xa0Technical Skills We Are Looking For: Programming: Java, C#, C++, SQL, HTML5, CSSFrameworks: Spring Boot, Spring MVC, Hibernate, Restful Web ServicesDatabase: Microsoft Access, MySQL, MongoDB, SQLIDE: Visual Studio, EclipseReport this jobDice Id: 10124918Position Id: 7676417',
#   'date': datetime.datetime(2022, 11, 22, 20, 32, 25),
#   'raw_date': '2022-11-22T20:32:25.000Z',
#   'city': 'Dallas',
#   'state': 'TX',
#   'country': 'US',
#   'zip': '75201',
#   'points': {'type': 'MultiPoint', 'coordinates': [[-96.799427, 32.78776]]},
#   'remote': False,
#   'source': 'dice'},
#  {'title': 'JUNIOR SOFTWARE ENGINEER',
#   'company': 'Incedo Inc',
#   'link': 'https://www.dice.com/jobs/detail/JUNIOR-SOFTWARE-ENGINEER-Incedo-Inc-Irving-TX-75014/10476889/7792457',
#   'description': "Associate Software Engineer -\xa0\xa0ResponsibilitiesDesign, develop, test, deploy, maintain and improve product and platform software.Manage individual project priorities, deadlines and deliverables.\xa0Skills &\xa0QualificationsBachelor's in Computer Science, Engineering, Mathematics or any Technology/ Programming coursesMid-level programming skill in any one of the programming languages such as Java, Scala, C#, JavaScriptProficiency in a scripting language such as python or shell scripts is preferredFamiliar with Serverless development in any of the cloud stackMid-level proficiency in SQL ProgrammingFamiliar with version control and CI/CDStrong analytical, communication and interpersonal skillsInterested in configuring, maintaining, and enhancing current features and functionalities of the system\xa0Report this jobDice Id: Incedo IncPosition Id: 7792457",
#   'date': datetime.datetime(2023, 3, 1, 17, 28, 38),
#   'raw_date': '2023-03-01T17:28:38.000Z',
#   'city': 'Irving',
#   'state': 'TX',
#   'country': 'US',
#   'zip': '75014',
#   'points': None,
#   'remote': False,
#   'source': 'dice'},
#  {'title': 'Junior Software Engineer (Public...',
#   'company': 'Motion Recruitment',
#   'link': 'https://www.dice.com/jobs/detail/Junior-Software-Engineer-%28Public-Trust-clearance%29-Motion-Recruitment-Washington-DC-20001/10105282/555271',
#   'description': 'A company in the government space is working with the FCC and they are looking to hire on a Junior Full Stack. This is a full-time fully remote role with an office located in Ashburn, VA. The tech stack they are using is Java, Angular, JavaScript, Node, and AWS.  As a full-stack engineer, you will be working on a large modernization project with the FCC and will have the opportunity to work with new technologies and new development.  Want to know more?? Apply today to be considered and to hear more about this role!! Required Skills & Experience  Java Spring Boot Angular JavaScript Node AWS  Desired Skills & Experience  1-3 Professional years of experience Public Trust  What You Will Be Doing Daily Responsibilities  80% Hands On 20% Team Collaboration  The Offer You will receive the following benefits:  Medical Insurance Dental Benefits Vision Benefits Paid Time Off (PTO)  Applicants must be currently authorized to work in the US on a full-time basis now and in the future.  #LI-MY2Report this jobDice Id: 10105282Position Id: 555271',
#   'date': None,
#   'raw_date': None,
#   'city': None,
#   'state': None,
#   'country': None,
#   'zip': None,
#   'points': {'type': 'MultiPoint', 'coordinates': [[-77.017739, 38.910353]]},
#   'remote': None,
#   'source': 'dice'},
#  {'title': 'Junior Software Developer',
#   'company': 'Motion Recruitment',
#   'link': 'https://www.dice.com/jobs/detail/Junior-Software-Developer-Motion-Recruitment-Cary-NC-27511/10105282/551695',
#   'description': 'Job Description My team and I are working with a company that helps Hospitals and Health Care Clinics stay under compliance. This company is looking for developers to help in the production of software design and development. Candidates who are enjoy solving complex problems on their own, while also working with their team and taking opportunities to learn from senior and lead developers. If you have at least 1 year of professional experience working with .NET Core, C#, Web APIs, and experience using Vue.JS - or any other JavaScript framework you might be a great fit for this role. This is a great full-time position for Cary candidate looking for an opportunity grow their skillset and work with new technologies, and full software development lifecycles. Required Skills & Experience  1+ years of professional experience .NET Core C# APIs SQL Vue.js, React, or Angular  Desired Skills & Experience  Eager to learn Team Player Great Communication  What You Will Be Doing Tech Breakdown  70% Backend 30% Frontend  Daily Responsibilities  100% Hands On 30% Maintenance Duties 40% Team Collaboration  The Offer You will receive the following benefits:  Hybrid Workplace Medical Insurance Dental Benefits Vision Benefits Paid Time Off (PTO) 401(k)   Applicants must be currently authorized to work in the US on a full-time basis now and in the future.Report this jobDice Id: 10105282Position Id: 551695',
#   'date': datetime.datetime(2023, 5, 27, 0, 13, 46),
#   'raw_date': '2023-05-27T00:13:46.000Z',
#   'city': 'Washington',
#   'state': 'DC',
#   'country': 'US',
#   'zip': '20001',
#   'points': {'type': 'MultiPoint', 'coordinates': [[-78.788528, 35.763414]]},
#   'remote': False,
#   'source': 'dice'},
#  {'title': 'Junior Software Engineer -Remote -...',
#   'company': 'Alldus',
#   'link': 'https://www.dice.com/jobs/detail/Junior-Software-Engineer-%26%2345Remote-%26%2345-Clearance-requuiered-Alldus---/91092880/7892674',
#   'description': "Description:The client \xa0is looking for a Software Engineer/Developer to join the authentication services team supporting the Department of Defense (DoD) High Performance Computing Modernization Program (DoD HPCMP).\xa0 This is a virtual position that can be accomplished from anywhere in the continental US.The successful candidate will support the development, testing, and deployment of authentication and identity management capabilities enabling access to DoD supercomputers and infrastructure across multiple locations.\xa0 Responsibilities will include working with a team of developers and engineers to review and define configurations, develop and update authentication applications and services, and develop and implement testing processes.Flexibility in approach to finding solutions is essential, as well as the ability to understand and act on the customer needs and priorities and learn new technologies quickly. Occasional off-hours activity will be required to perform updates and take part in service restoration efforts. Responsibilities include:Provides support in software development phases that include, but are not limited to:Design (database, GUI, web services, standalone applications)Performance TuningDevelopment and maintenance of authentication applications using multiple languagesUnit and Integration TestingRelease/Patch BuildDeployment/Installation in test and production environmentsUses applicable methodologies, modeling/estimating techniques, tools, applications, systems, software, and databases to perform assigned tasks.Contributes to or develops technical documentation (e.g., Test Cases, Test Plan, updates to application administration documentation)\xa0Required Skills and ExperienceRecent experience with C/C++, Python, Perl, and Linux Bash scripting.Experience with writing SQL queries, SQL query optimization, and SQL development tools such as Oracle SQL DeveloperFamiliarity with authentication systems and protocols, including Kerberos, OpenID Connect, and two-factor authenticationFamiliarity with decomposing requirements to provide estimates for completionSelf-starter with ability to multi-task and meet deadlines consistently\xa0Desired Skills and ExperienceDevSecOps team experienceVMware Server AdministrationNetworking ExperienceGitLab use as a DevOps platform\xa0Other Requirements:Secret Security ClearanceDoD 8570 IAT II (or better) Certification (i.e. Security+)\xa0Typical Education and Experience: Bachelor's degree in Computer Science or other related field/concentration and three (3) years or more experience, Additional 4 years of experience in lieu of degreeReport this jobDice Id: 91092880Position Id: 7892674",
#   'date': datetime.datetime(2023, 4, 14, 0, 15, 38),
#   'raw_date': '2023-04-14T00:15:38.000Z',
#   'city': 'Cary',
#   'state': 'NC',
#   'country': 'US',
#   'zip': '27511',
#   'points': None,
#   'remote': False,
#   'source': 'dice'},
#  {'title': 'Jr. Application Developer',
#   'company': 'Golden Resources. Inc.',
#   'link': 'https://www.dice.com/jobs/detail/Jr.-Application-Developer-Golden-Resources.-Inc.-Overland-MO-63114/10121014/7887123',
#   'description': 'Our client is seeking an Application Developer to join their Team!The Position:The Application Developer will be responsible for the following:Design and develop solutions leveraging our current tech stack (Angular, C#, SQL, ETL, REST API)Build, configure, troubleshoot, and maintain integrations built in Azure Logic Apps or other integration toolsDesign, develop, implement, administer, and provide support for integrationsEngage with business and technical stakeholders to achieve key objectives and solve problemsLead software development initiatives and projectsMaintain technology standards and drive innovation & best practicesProactively identify gaps in the existing infrastructure and development process, acting as a catalyst for change for greater efficiencyBe the best version of yourself every day in a positive, rewarding, and fun environmentReport this jobDice Id: 10121014Position Id: 7887123',
#   'date': datetime.datetime(2023, 5, 15, 17, 11, 26),
#   'raw_date': '2023-05-15T17:11:26.000Z',
#   'city': None,
#   'state': None,
#   'country': None,
#   'zip': None,
#   'points': {'type': 'MultiPoint', 'coordinates': [[-90.363674, 38.702256]]},
#   'remote': True,
#   'source': 'dice'},
#  {'title': 'Junior software Developer',
#   'company': 'INNOVIT USA INC',
#   'link': 'https://www.dice.com/jobs/detail/Junior-software-Developer-INNOVIT-USA-INC--AK-/90737436/2023%26%2345271',
#   'description': "Junior Developer Belvedere Tiburon, California   - Needs Power App interface development experience - Team's environment is mostly Microsoft stack - needs good experience with that - SCADA environment experience - Remote server management, set up new environments, maintaining/patching - Doesn't need to be an expert in C#/C++, but some familiarity good. - JavaScript skills for updating some web applications. - Data skills - MS SQL - Can be remote - 3+ years experience - Business System Analyst looking to get into Technology side.  Report this jobDice Id: 90737436Position Id: 2023-271",
#   'date': datetime.datetime(2023, 5, 10, 15, 37, 27),
#   'raw_date': '2023-05-10T15:37:27.000Z',
#   'city': 'Overland',
#   'state': 'MO',
#   'country': 'US',
#   'zip': '63114',
#   'points': None,
#   'remote': False,
#   'source': 'dice'},
#  {'title': 'Junior Software Engineer -...',
#   'company': 'Nigel Frank International',
#   'link': 'https://www.dice.com/jobs/detail/Junior-Software-Engineer-%26%2345-Springfield%2C-VA-%26%2345-%24150k-Nigel-Frank-International-Springfield-VA-22152/10371697/IH5172023%26%234539',
#   'description': "Junior Software Engineer - Springfield, VA - $150kThe Junior Systems Engineer provides customer-facing consulting services, technical expertise, engineering services, and operational support to clients as part of an account team. You will provide recommendations based on industry expertise in requirements analysis, functional design, and deployment of complex technology solutions across a variety of networks. Role & ResponsibilitiesDevelopment and maintenance of documentation pertaining to their client's network and infrastructureThe IT Infrastructure of external customer environments could include, but is not limited to, network connectivity and utilization, Windows server administration, virtualization, performance tuning, backup and restoreYou will be responsible for the development and maintenance of documentation pertaining to their client's network and infrastructure Skills & QualificationsLeverage industry experience in analysis, design, configuration, and implementation of IT infrastructures including but not limited to, routers, switches, firewalls, virtual environments, wireless networks, backup devices, security awareness, etcSQL Database Admin, Network diagnostic and monitoring software, Disaster Recovery planning and implementationMicrosoft Windows 2016 MCSE, MCITP or equivalentPython, JavaScript, SharePoint, JIRA, Infrastructure (Puppet, Ansible, Chef, Salt, CloudFormation or Terraform)3+ years of related systems architect experienceDevOpsBenefitsGenerous PTO$150k - $160k Based on Experience401k To apply please send resumes to Isaac Heatley at  or call . Interviews happening daily! Nigel Frank International is the global leader for Microsoft Dynamics recruitment, advertising more Dynamics CRM jobs than any other agency. We deal with both Microsoft Partners & End Users throughout North America. By specializing solely in placing candidates in the Microsoft Dynamics market I have built relationships with most of the key employers in North America and have an unrivalled understanding of where the best opportunities and Dynamics CRM jobs are.I understand the need for discretion and would welcome the opportunity to speak to any Microsoft Dynamics CRM candidates that are considering a new career or job either now or in the future. Confidentiality is of course guaranteed. For information on the Microsoft Dynamics market and some of the opportunities and Dynamics CRM jobs that are available I can be contacted on . Please see  for more fantastic Microsoft Dynamics opportunities!Nigel Frank International Inc. is acting as an Employment Agency in relation to this vacancy.Report this jobDice Id: 10371697Position Id: IH5172023-39",
#   'date': datetime.datetime(2023, 5, 17, 13, 46, 7),
#   'raw_date': '2023-05-17T13:46:07.000Z',
#   'city': None,
#   'state': 'AK',
#   'country': 'US',
#   'zip': None,
#   'points': {'type': 'MultiPoint', 'coordinates': [[-77.232029, 38.774493]]},
#   'remote': False,
#   'source': 'dice'},
#  {'title': 'Junior Software Engineer / Local...',
#   'company': 'Motion Recruitment',
#   'link': 'https://www.dice.com/jobs/detail/Junior-Software-Engineer-%26%2347-Local-Philadelphia-Candidates-Motion-Recruitment-Philadelphia-PA-19019/10105282/551799',
#   'description': "Job Description Are you a developer looking to join a Top 100 awarded Government Technology company? This consulting software firm provides services to various government entities from schools to municipalities to local and state governments. They have been in business for over 45 years and have serviced almost 2,000 municipalities with a 98% client retention.  This company is looking to hire a Developer with about 3 years of experience working with Java and Spring Boot. In this role, you will get to work on the maintenance and development of their products which host different government entities' information. They use TypeScript but are looking for any kind of experience or familiarity with working on the frontend. You will also get the chance to modernize a lot of their client's systems, especially using Microservices and AWS. They offer extensive and ongoing training, making this is a great opportunity for those early in their career looking to expand their skillset.  This is a full-time, salaried position. They are looking for candidates to come onsite to their Atlantic County, New Jersey office 2 times a month. Required Skills & Experience  Java Spring Boot JavaScript BS in CS or related field  Desired Skills & Experience  AWS MySQL Typescript Python  What You Will Be Doing Tech Breakdown  80% Backend 20% Frontend  Daily Responsibilities  100% Development  The Offer  Competitive Salary  You will receive the following benefits:  Medical Insurance Dental Benefits Vision Benefits Paid Time Off (PTO) 401(k) including match Report this jobDice Id: 10105282Position Id: 551799",
#   'date': datetime.datetime(2023, 5, 18, 12, 11, 1),
#   'raw_date': '2023-05-18T12:11:01.000Z',
#   'city': 'Springfield',
#   'state': 'VA',
#   'country': 'US',
#   'zip': '22152',
#   'points': None,
#   'remote': False,
#   'source': 'dice'},
#  {'title': 'JR. SOFTWARE SALES EXECUTIVE',
#   'company': 'Universal Business Solutions',
#   'link': 'https://www.dice.com/jobs/detail/JR.-SOFTWARE-SALES-EXECUTIVE-Universal-Business-Solutions-Alpharetta-GA-30004/10116519/7878271',
#   'description': ' SOFTWARE SALES EXECUTIVEALPHARETTA, GAFULL TIME\xa0WHO WE ARE:\xa0At UBS our goal is to make sure our clients’ customer journey is not only seamless but exceeds their expectations. If you have excellent Customer Service and a Sales track record, come learn about the Software Industry with us!We are looking for several\xa0Sales\xa0Executives to join our team and participate in different projects. Excellent opportunity for professionals looking to develop in one of the fastest growing industries!\xa0RESPONSIBILITIES: Responsible for New Business and Lead Generation Identify prospective clients in your assigned territory through provided resources and independent research.Manage pipeline in CRM tool to provide forecasts on weekly updates to your\xa0Sales Manager.Navigate deal cycles 1-3 months in length.Build relationships with key decision-makers and influencers.\xa0Qualifications:Experience in\xa0Software Sales 1 year plus of proven track\xa0sales\xa0record AND sales experience selling B2B Software Solutions Bachelor’s Degree or comparable work experience requiredStrong oral and written communication skillsStrong relationship building\xa0  \xa0Report this jobDice Id: 10116519Position Id: 7878271',
#   'date': datetime.datetime(2023, 5, 30, 0, 22, 13),
#   'raw_date': '2023-05-30T00:22:13.000Z',
#   'city': 'Philadelphia',
#   'state': 'PA',
#   'country': 'US',
#   'zip': '19019',
#   'points': {'type': 'MultiPoint', 'coordinates': [[-84.291894, 34.145614]]},
#   'remote': False,
#   'source': 'dice'},
#  {'title': 'Junior Software Automated Testing...',
#   'company': 'The Proven Method',
#   'link': 'https://www.dice.com/jobs/detail/Junior-Software-Automated-Testing-Engineer-The-Proven-Method-Alpharetta-GA-30004/proven/7912880',
#   'description': 'Our client is an in ternational Quality Assurance and testing firm that is looking for a resouce to join their team on a\xa0 6-9 month contract to hire engagement\xa0Location : Alpharetta GA(3-4 Days aweek onsite) Local candidates preferredMust be able to work without sponsorship now and in the future.\xa0No of roles : 4JD:-Test engineer with 2-3\xa0 yrs of hands on testing experience.-Must have hands on knowledge on Selenium & Java-Experience with Python skills.Resource should have exposure to multiple tools \xa0(prefer Selenium, Java and Python – Python is highest priority)Need Angular JS with Python Robot framework\xa0Eclipse is nice to have not a must- Must be able to attend the office in person 3 days a week.- Should be good in communication skills.Report this jobDice Id: provenPosition Id: 7912880',
#   'date': None,
#   'raw_date': None,
#   'city': None,
#   'state': None,
#   'country': None,
#   'zip': None,
#   'points': {'type': 'MultiPoint', 'coordinates': [[-84.291894, 34.145614]]},
#   'remote': None,
#   'source': 'dice'},
#  {'title': 'junior SQL Server database and...',
#   'company': 'Leidos',
#   'link': 'https://www.dice.com/jobs/detail/junior-SQL-Server-database-and-.Net-Software-Developer-Leidos-Bethesda-MD-20889/SCNCAPI2/R%26%234500112391',
#   'description': "Description  Looking for an opportunity to make an impact? At Leidos, we deliver innovative solutions through the efforts of our diverse and talented people who are dedicated to our customers' success. We empower our teams, contribute to our communities, and operate sustainable. Everything we do is built on a commitment to do the right thing for our customers, our people, and our community. Our Mission, Vision, and Values guide the way we do business.Your greatest work is ahead!We are in search of junior SQL Server database and .Net Software Developer to join our task force at the Government Health and Safety Solutions Operation in Bethesda, MD. This opening will support federal health enterprise systems.Research, design, develop and maintain enterprise system for our Leidos clients using the .Net, ASP.Net MVC, .Net Core, C#, T-SQL, Visual Studio. This involves the use of user stories, acceptance criteria and other software engineering artifacts.Begin your journey of a flourishing and meaningful career, share your resume with us today!Responsibilities Include: The candidate will be responsible for Provide technical support and guidance to end users, answering their queries and assisting them in resolving application-related problems. He/she will support the software configuration management process and understand software components and their interface requirements.This position requires someone who is proactive and passionate about ensuring the quality of software deliverables and continuous improvement, as well as, and can communicate with the users and development teams what is required to achieve this effectively on tasks.Maintain key components of software applications using ASP.NET MVC, .Net Core, REST, XMLDevelop code in C# and ASP.NET framework using Microsoft Visual StudioDevelop database scripts in SQL Server using SQL and T-SQLDesign and develop web applications user interface using HTML5, Javascript, Bootstrap, JqueryReceive and analyze user-reported issues with web applications and Adobe LMS system, identify the root cause of the problem.Collaborate with LMS application users and stakeholders to gather detailed information about the issue and understand its impact on user experience.Develop and implement effective solutions to fix ASP.NET, C# application issues. Test and validate fixes to ensure they resolve the reported issues and do not introduce new problems.Document and maintain a comprehensive log of all application issues, including their root causes, solutions, and steps taken for future reference.Coordinate with cross-functional teams, such as developers, Database administrators, and system administrators, to address complex application issues that require broader expertise.Continuously monitor and analyze application logs, error reports, and user feedback to proactively identify and resolve potential issues before they impact users.Provide technical support and guidance to end users, answering their queries and assisting them in resolving application-related problems.Write and optimize SQL queries to extract, manipulate, and analyze data. Troubleshoot and resolve SQL Server database-related issues and errors.Collaborate with other team members to support application development and ensure seamless integration between the application and the database.Stay updated with the latest web development technologies, frameworks, and best practices to enhance troubleshooting skills and knowledge.Required Education:Bachelor's Degree preferably in Computer Science or IT related discipline and 2 years of related experience is requiredRequired Experience & Skills:Experienced with C#, ASP.NET, ADO.Net, Entity Framework, Web APIExperience with RDMS and database design and troubleshooting (SQL Server, T-SQL)Experience with developing Sql server scripts, stored procedures, T-SQL and functionsAble to multi-task and work in a dynamic, fast-paced environmentAble to communicate with users promptly and effectiv ...
#   'date': datetime.datetime(2023, 5, 3, 17, 45, 6),
#   'raw_date': '2023-05-03T17:45:06.000Z',
#   'city': 'Alpharetta',
#   'state': 'GA',
#   'country': 'US',
#   'zip': '30004',
#   'points': None,
#   'remote': False,
#   'source': 'dice'},
#  {'title': 'FullStack Software Developer -...',
#   'company': 'Randstad Technologies',
#   'link': 'https://www.dice.com/jobs/detail/FullStack-Software-Developer-%26%2345-Junior-Randstad-Technologies-Bellaire-TX-77401/cxsapwma1/1006460',
#   'description': "job summary:Junior Software Developer is responsible for Design, develop code, test and maintain websites and applications based on per-defined requirements for programs, functions, services, using advanced programming languages as part of a team and/or individually to support business initiatives as directed by IT management.\xa0location: BELLAIRE, Texasjob type: Permanentsalary: $70,000 - 90,000  per yearwork hours: 8am to 5pmeducation: Bachelors\xa0responsibilities:Angular & .NET Core SQLExperience doing both front end and back end development (Full stack)Agile environment Not really concerned with Javascript or C#.Want someone who can assess what needs done and utilize the right technology for the challenge.Someone open to using different technologies. COMPUTER/ SYSTEMS/ SOFTWARE PROFICIENCY:  Web development experience using ASP.NET MVC, C#, HTML5, CSS, JavaScript, jQuery and BootstrapGood understanding of database development using Microsoft SQL ServerFamiliarity with Microsoft Azure DevOps Server (TFS)Familiarity with REST API Service Essential Functions:Builds, enhances, and maintains in-house web sites, databases, web applications as well as third-party applications/systems/tools as assigned.Would be able to work with limited or sometimes no specifications.Adheres to coding standards defined by technical management.Write SQL statements and develop software using .NET framework.\xa0qualifications:Experience level: ExperiencedMinimum 2 years of experienceEducation: Bachelors (required)\xa0skills: .NET (2 years of experience is required)SQL (2 years of experience is required) Equal Opportunity Employer: Race, Color, Religion, Sex, Sexual Orientation, Gender Identity, National Origin, Age, Genetic Information, Disability, Protected Veteran Status, or any other legally protected group status.At Randstad, we welcome people of all abilities and want to ensure that our hiring and interview process meets the needs of all applicants. If you require a reasonable accommodation to make your application or interview experience a great one, please contact   Pay offered to a successful candidate will be based on several factors including the candidate's education, work experience, work location, specific job duties, certifications, etc.  In addition, Randstad offers a comprehensive benefits package, including health, an incentive and recognition program, and 401K contribution (all benefits are based on eligibility).   For certain assignments, Covid-19 vaccination and/or testing may be required by Randstad's client or applicable federal mandate, subject to approved medical or religious accommodations. Carefully review the job posting for details on vaccine/testing requirements or ask your Randstad representative for more information. Report this jobDice Id: Randstad TechnologiesPosition Id: 1006460",
#   'date': datetime.datetime(2023, 5, 31, 19, 40, 17),
#   'raw_date': '2023-05-31T19:40:17.000Z',
#   'city': 'Alpharetta',
#   'state': 'GA',
#   'country': 'US',
#   'zip': '30004',
#   'points': {'type': 'MultiPoint', 'coordinates': [[-95.460905, 29.704019]]},
#   'remote': False,
#   'source': 'dice'}]

# %%
html = requests.get('https://www.dice.com/job-detail/ecb88987-be87-47c0-b6b6-8e1671fa617a').text
soup = BeautifulSoup(html, 'html')

json_text = soup.find('script', id="__NEXT_DATA__")
jobdic = json.loads(json_text.text)
jobdata = jobdic['props']['pageProps']['initialState']['api']['queries']
firstkey = list(jobdata.keys())[0]
locationdetail = jobdata[firstkey]['data']['locationDetail']
locationdata = locationdetail['locations'][0]
dateposted = jobdata[firstkey]['data']['datePosted']
dateposted = datetime.fromisoformat(dateposted)
dateposted
# Out:
# datetime.datetime(2023, 3, 2, 17, 8, 27, tzinfo=datetime.timezone.utc)
